# %% [markdown]
# <a href="https://colab.research.google.com/github/Salahuddin56/Twitter-Sentiment-Analysis-pipeline-using-NLP-/blob/main/Twitter_Sentiment_Analysis_pipeline_using_NLP_%5BGroup_9%5D_%5BVersion_1_2%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # **Name: Salahuddin Elias Khan**
#
# # **ID: 23-93143-3**
# # **Group: 9**
#
# **Course: NATURAL LANGUAGE PROCESSING [MScCS] [A]**
#
# ---

# %%
# !pip install transformers

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import torch
import transformers as ppb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***Pulling The CSV Dataset Directly from Colab***

# %%
#PULLING THE CSV FILES
df = pd.read_csv("Twitter_Data.csv", header=None)

# %%
batch_1 = df[:2000]

# %%
batch_1[1].value_counts()
# Out:
# 1           867
# 0           706
# -1          426
# category      1
# Name: 1, dtype: int64

# %%
batch_1.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.DistilBertModel, ppb.DistilBertTokenizer, 'distilbert-base-uncased')

tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

# %%
batch_1 = batch_1.dropna()

# %%
print(batch_1.head())
# Out:
#                                                    0         1
# 0                                         clean_text  category
# 1  when modi promised “minimum government maximum...        -1
# 2  talk all the nonsense and continue all the dra...         0
# 3  what did just say vote for modi  welcome bjp t...         1
# 4  asking his supporters prefix chowkidar their n...         1

# %%
print(batch_1.tail())
# Out:
#                                                       0  1
# 1995                               only one choice modi  0
# 1996  eam have decided not criticise bullshits befor...  0
# 1997  modi meetings andhra pradesh march april modi ...  0
# 1998  one vote can make all the difference anil kapo...  1
# 1999       yes want see this movie great narendra modi   1

# %%
tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))

# %%
max_len = 0
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])

# %%
np.array(padded).shape
# Out:
# (1999, 84)

# %%
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape
# Out:
# (1999, 84)

# %%
input_ids = torch.tensor(padded)
attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states = model(input_ids, attention_mask=attention_mask)

# %%
features = last_hidden_states[0][:,0,:].numpy()

# %%
labels = batch_1[1]

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels)

# %%
lr_clf = LogisticRegression()
lr_clf.fit(train_features, train_labels)
# Out:
# LogisticRegression()

# %%
lr_clf.score(test_features, test_labels)
# Out:
# 0.594
